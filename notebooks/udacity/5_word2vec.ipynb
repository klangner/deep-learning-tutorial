# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return tf.compat.as_str(f.read(name)).split()
    f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.994379
# Nearest to their: sails, beltaine, succinctly, bassett, peroxide, korfball, labelling, ragnar,
# Nearest to six: gne, puckett, danios, violinist, winger, spare, hillery, decompression,
# Nearest to up: microprocessors, trappings, suspense, scaly, motivational, laptops, secular, coordinates,
# Nearest to b: bobo, stunt, lublin, alpina, indictment, researched, looted, assume,
# Nearest to war: blu, snl, huntingdon, bloodiest, alleviation, lundy, trombonist, wounded,
# Nearest to by: visualize, dk, comiskey, bua, homonyms, counterfactual, afghanistan, antipopes,
# Nearest to no: disposal, bikram, osnabr, chera, joaquin, aquinas, rowers, individual,
# Nearest to these: disperse, zoologist, vigilant, secretaries, massimo, dissociative, moctezuma, simultaneity,
# Nearest to of: amoral, sourced, gallup, fips, parsed, nkvd, solemnity, baba,
# Nearest to been: flourishing, difranco, shallower, incrimination, barking, pounder, orphanage, originates,
# Nearest to united: childish, choi, manley, leste, pleasuredome, applauded, mistral, mehmed,
# Nearest to two: tribal, anabolic, noord, paso, gargoyles, blavatsky, colombian, comte,
# Nearest to and: perl, boeotia, cursus, eplf, prosper, lam, gripping, close,
# Nearest to only: steno, foley, cinque, complemented, sash, sucker, immensely, reproduce,
# Nearest to three: campus, doubtless, chileans, silva, dave, commandments, stipulates, belligerent,
# Nearest to may: massawa, advisor, payoff, gin, homages, respective, mixture, devotees,
# Average loss at step 2000: 4.359679
# Average loss at step 4000: 3.863361
# Average loss at step 6000: 3.788189
# Average loss at step 8000: 3.687129
# Average loss at step 10000: 3.607780
# Nearest to their: his, its, williamson, the, bassett, sweetness, eclipses, challengers,
# Nearest to six: eight, three, seven, five, nine, four, zero, two,
# Nearest to up: suspense, confront, presume, himself, depots, repealing, laptops, harvard,
# Nearest to b: d, uwe, substituted, shawn, fischer, snipers, alpina, christine,
# Nearest to war: huntingdon, nga, violate, dso, yukio, jamo, rouen, alleviation,
# Nearest to by: was, gifs, blessed, abercorn, relocating, sporadic, widths, analogous,
# Nearest to no: aquinas, growth, convergent, intra, chera, ptr, also, rowers,
# Nearest to these: sarti, piccadilly, graduation, ulfilas, uppermost, nonnegative, secretaries, faux,
# Nearest to of: in, for, same, extracts, microphone, on, and, terminated,
# Nearest to been: was, vespucci, originates, be, filtered, flourishing, orphanage, hiddenstructure,
# Nearest to united: same, mehmed, colic, childish, applauded, graziani, leste, refering,
# Nearest to two: three, five, four, six, eight, seven, one, nine,
# Nearest to and: or, s, barbara, who, american, unequalled, d, of,
# Nearest to only: holly, steno, bananas, deutsche, topic, entanglement, hijacking, sash,
# Nearest to three: six, seven, eight, four, five, two, nine, zero,
# Nearest to may: can, company, would, space, will, cooler, could, mx,
# Average loss at step 12000: 3.602265
# Average loss at step 14000: 3.567152
# Average loss at step 16000: 3.410154
# Average loss at step 18000: 3.457251
# Average loss at step 20000: 3.538442
# Nearest to their: his, its, the, her, some, sweetness, these, inciting,
# Nearest to six: eight, seven, three, five, four, nine, two, zero,
# Nearest to up: him, back, presume, suspense, himself, confront, lambasted, incised,
# Nearest to b: d, accident, profiting, shires, reworking, fowler, lector, shawn,
# Nearest to war: huntingdon, nga, glee, violate, dso, pilsener, alleviation, stockpiles,
# Nearest to by: be, was, abercorn, disrupting, for, were, with, from,
# Nearest to no: any, growth, aquinas, convergent, a, usually, watchers, it,
# Nearest to these: some, many, which, several, all, piccadilly, uppermost, are,
# Nearest to of: provision, for, amoral, peacock, evers, in, rouse, predecessors,
# Nearest to been: be, become, was, ballistics, had, were, vespucci, clerk,
# Nearest to united: same, mehmed, childish, applauded, colic, cmmi, hamsters, refering,
# Nearest to two: three, five, six, four, seven, eight, one, zero,
# Nearest to and: or, in, spill, for, american, ekam, from, although,
# Nearest to only: holly, newman, hijacking, not, bananas, topic, entanglement, scalability,
# Nearest to three: six, two, seven, four, five, eight, zero, nine,
# Nearest to may: can, will, would, could, should, must, might, cooler,
# Average loss at step 22000: 3.498564
# Average loss at step 24000: 3.492413
# Average loss at step 26000: 3.476319
# Average loss at step 28000: 3.478778
# Average loss at step 30000: 3.503177
# Nearest to their: its, his, the, her, these, some, our, catv,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to up: him, back, himself, lambasted, presume, actuality, incestuous, koans,
# Nearest to b: d, toto, bandy, profiting, reworking, stat, shires, substituted,
# Nearest to war: nga, huntingdon, violate, helper, glee, stockpiles, tackles, jost,
# Nearest to by: under, with, dubrovnik, in, was, as, abercorn, during,
# Nearest to no: any, a, eos, convergent, growth, trumpeter, aquinas, it,
# Nearest to these: some, many, several, they, their, those, all, are,
# Nearest to of: in, and, binge, subfamilies, logical, rouse, secret, terminated,
# Nearest to been: become, was, be, were, ballistics, clerk, already, had,
# Nearest to united: same, childish, mehmed, borne, colic, applauded, hamsters, leste,
# Nearest to two: four, three, one, five, seven, eight, six, zero,
# Nearest to and: or, but, who, in, of, however, gaspar, saturated,
# Nearest to only: marred, topic, entanglement, still, holly, scalability, usually, newman,
# Nearest to three: five, four, seven, two, six, eight, nine, zero,
# Nearest to may: can, would, will, could, should, must, might, cooler,
# Average loss at step 32000: 3.503144
# Average loss at step 34000: 3.492793
# Average loss at step 36000: 3.448540
# Average loss at step 38000: 3.296307
# Average loss at step 40000: 3.424692
# Nearest to their: its, his, her, the, these, some, any, my,
# Nearest to six: four, seven, eight, five, three, nine, two, zero,
# Nearest to up: him, back, them, out, down, himself, suspense, incestuous,
# Nearest to b: d, e, stat, n, substituted, concoction, UNK, toto,
# Nearest to war: huntingdon, glee, nga, violate, stockpiles, lundy, alcoholism, korn,
# Nearest to by: with, when, alfaro, abercorn, dubrovnik, disrupting, magna, be,
# Nearest to no: any, every, intra, trumpeter, convergent, catechism, usually, growth,
# Nearest to these: some, many, several, those, they, such, both, all,
# Nearest to of: in, microphone, for, telnet, from, shun, same, missourians,
# Nearest to been: become, was, be, were, ballistics, publically, already, rationally,
# Nearest to united: finegold, hamsters, borne, mistral, hawaiian, reconsider, leste, childish,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to and: or, but, including, like, reactivated, angkor, while, cadres,
# Nearest to only: just, marred, bananas, scalability, topic, promptly, hyatt, still,
# Nearest to three: four, six, seven, two, five, eight, nine, zero,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Average loss at step 42000: 3.432399
# Average loss at step 44000: 3.459108
# Average loss at step 46000: 3.447936
# Average loss at step 48000: 3.357297
# Average loss at step 50000: 3.379980
# Nearest to their: its, his, her, the, these, our, my, some,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to up: him, out, back, them, down, off, himself, koans,
# Nearest to b: d, stat, ibn, krakatau, o, r, clyde, laodicea,
# Nearest to war: glee, alcoholism, lundy, nga, korn, huntingdon, violate, stockpiles,
# Nearest to by: under, through, was, millionaire, abercorn, with, dubrovnik, while,
# Nearest to no: any, intersecting, trumpeter, a, another, watchers, persistent, she,
# Nearest to these: some, many, several, both, those, such, their, imitation,
# Nearest to of: and, in, including, bicycling, thematically, styria, deformations, containing,
# Nearest to been: become, be, already, ballistics, was, publically, were, plunge,
# Nearest to united: finegold, hamsters, mistral, reconsider, childish, cmmi, hawaiian, borne,
# Nearest to two: three, six, one, four, eight, seven, five, zero,
# Nearest to and: or, but, including, of, however, in, milgram, basket,
# Nearest to only: usually, still, rhea, moon, mech, generally, technocracy, welland,
# Nearest to three: four, seven, six, eight, two, five, nine, zero,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Average loss at step 52000: 3.433448
# Average loss at step 54000: 3.424961
# Average loss at step 56000: 3.437674
# Average loss at step 58000: 3.391307
# Average loss at step 60000: 3.394285
# Nearest to their: its, his, her, the, whose, our, these, some,
# Nearest to six: four, five, eight, nine, seven, three, zero, two,
# Nearest to up: out, down, him, back, them, off, suspense, incestuous,
# Nearest to b: d, c, n, unloading, w, r, clyde, o,
# Nearest to war: nga, alcoholism, lundy, glee, tackles, violate, korn, aardwolf,
# Nearest to by: under, halved, through, tobit, with, without, abercorn, boudin,
# Nearest to no: any, trumpeter, a, there, intersecting, grabbing, dilapidated, tailpiece,
# Nearest to these: some, many, several, those, both, which, they, different,
# Nearest to of: in, for, avc, same, containing, zimmerman, logical, counterbalanced,
# Nearest to been: become, be, already, ballistics, were, was, publically, plunge,
# Nearest to united: finegold, constitution, colic, cmmi, mistral, hamsters, childish, reconsider,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to and: or, but, whereas, including, although, from, while, for,
# Nearest to only: usually, mech, still, marred, also, first, entanglement, scalability,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to may: can, could, would, will, should, must, might, does,
# Average loss at step 62000: 3.238070
# Average loss at step 64000: 3.253049
# Average loss at step 66000: 3.405532
# Average loss at step 68000: 3.394752
# Average loss at step 70000: 3.358414
# Nearest to their: its, his, her, the, my, your, these, whose,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to up: down, him, out, them, back, off, incestuous, suspense,
# Nearest to b: d, w, r, unloading, laodicea, n, h, f,
# Nearest to war: lundy, alcoholism, glee, londonderry, rouen, nga, tackles, korn,
# Nearest to by: through, halved, under, using, be, abercorn, was, without,
# Nearest to no: any, there, intersecting, trumpeter, grabbing, athletes, little, formalize,
# Nearest to these: many, such, several, some, those, which, are, their,
# Nearest to of: including, include, assented, in, for, without, containing, dme,
# Nearest to been: become, be, was, already, were, had, ballistics, publically,
# Nearest to united: cmmi, finegold, colic, constitution, supreme, applauded, mistral, leste,
# Nearest to two: three, four, six, seven, one, five, eight, zero,
# Nearest to and: or, while, but, including, however, which, via, whose,
# Nearest to only: still, usually, irrationality, first, tintin, always, actually, considered,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Average loss at step 72000: 3.372240
# Average loss at step 74000: 3.344853
# Average loss at step 76000: 3.312082
# Average loss at step 78000: 3.353178
# Average loss at step 80000: 3.378580
# Nearest to their: its, his, her, my, our, your, both, the,
# Nearest to six: eight, five, four, seven, three, nine, two, zero,
# Nearest to up: out, down, off, them, him, back, incestuous, suspense,
# Nearest to b: d, w, clyde, unloading, c, ibn, stat, r,
# Nearest to war: glee, lundy, alcoholism, frequencies, tackles, korn, rouen, londonderry,
# Nearest to by: through, using, millionaire, boudin, under, halved, abercorn, dubrovnik,
# Nearest to no: any, little, grabbing, neuron, there, climatology, intersecting, another,
# Nearest to these: several, many, such, those, both, some, various, different,
# Nearest to of: in, vast, including, maureen, missourians, avc, assented, foreshadow,
# Nearest to been: become, be, already, was, were, had, ballistics, publically,
# Nearest to united: colic, finegold, constitution, cmmi, mistral, applauded, kansas, salad,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to and: or, hyacinthus, including, but, slr, gen, trash, basket,
# Nearest to only: still, usually, just, actually, first, tintin, marred, zimri,
# Nearest to three: four, seven, six, eight, two, five, nine, zero,
# Nearest to may: can, could, would, will, should, might, must, cannot,
# Average loss at step 82000: 3.409170
# Average loss at step 84000: 3.411978
# Average loss at step 86000: 3.384343
# Average loss at step 88000: 3.350436
# Average loss at step 90000: 3.365333
# Nearest to their: its, his, her, your, our, my, mongoloid, some,
# Nearest to six: eight, four, seven, five, nine, three, two, zero,
# Nearest to up: out, off, down, them, him, back, away, incestuous,
# Nearest to b: d, stat, r, j, ibn, c, unloading, processor,
# Nearest to war: rouen, glee, during, korn, alcoholism, wars, lundy, tackles,
# Nearest to by: through, under, dubrovnik, abercorn, with, using, from, seo,
# Nearest to no: any, little, another, only, grabbing, intersecting, there, formalize,
# Nearest to these: several, many, some, those, are, various, both, imitation,
# Nearest to of: including, in, microphone, avc, for, foreshadow, counterbalanced, pius,
# Nearest to been: become, be, already, was, were, had, ballistics, lenovo,
# Nearest to united: constitution, finegold, colic, cmmi, applauded, mistral, greeks, longest,
# Nearest to two: four, three, six, five, one, seven, eight, zero,
# Nearest to and: or, but, including, while, sacrificial, however, although, unsolvable,
# Nearest to only: still, actually, usually, even, no, tintin, rationalistic, always,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to may: can, could, would, should, might, will, must, cannot,
# Average loss at step 92000: 3.396801
# Average loss at step 94000: 3.250498
# Average loss at step 96000: 3.357558
# Average loss at step 98000: 3.243065
# Average loss at step 100000: 3.355107
# Nearest to their: its, his, her, your, our, the, my, these,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to up: out, off, him, back, them, down, incestuous, away,
# Nearest to b: d, stat, delicately, flagg, convicts, frustrations, ibn, swedish,
# Nearest to war: wars, dope, rouen, threatens, lundy, henderson, alcoholism, londonderry,
# Nearest to by: under, halved, through, when, reston, tobit, dubrovnik, without,
# Nearest to no: any, little, only, another, there, formalize, lemonade, trumpeter,
# Nearest to these: several, some, many, various, different, those, multiple, all,
# Nearest to of: assented, including, in, and, original, entire, vast, ngos,
# Nearest to been: become, be, already, was, recently, dinoflagellates, ballistics, were,
# Nearest to united: constitution, finegold, greeks, colic, dominican, mistral, cmmi, applauded,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to and: or, but, however, although, when, while, of, including,
# Nearest to only: still, tintin, no, always, nostalgic, usually, even, actually,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to may: can, could, should, must, would, might, will, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %pylab inline
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
